# %%
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df1.corr())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df1['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
# 3.50     9
# 1.50     9
# 1.00     4
# 1.25     3
# 3.48     3
# 2.01     2
# 4.08     2
# 2.23     2
# 2.03     2
# 3.18     2
# 2.31     2
# 2.24     2
# 6.50     2
# 4.30     2
# 2.20     2
# 3.76     2
# 3.25     2
# 2.75     2
# 1.44     2
# 3.23     2
# 1.01     1
# 2.45     1
# 1.47     1
# 3.61     1
# 2.54     1
#         ..
# 4.06     1
# 3.15     1
# 1.45     1
# 2.34     1
# 1.92     1
# 2.30     1
# 2.88     1
# 3.55     1
# 4.20     1
# 4.19     1
# 2.56     1
# 2.71     1
# 3.27     1
# 5.14     1
# 2.02     1
# 4.67     1
# 4.34     1
# 5.17     1
# 3.14     1
# 5.15     1
# 1.67     1
# 1.32     1
# 1.36     1
# 1.68     1
# 1.83     1
# 2.83     1
# 1.58     1
# 3.71     1
# 3.35     1
# 2.18     1
# Name: tip, Length: 123, dtype: int64

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Jointplot

# %%
w=sns.jointplot(x='tip',y='total_bill',data=df1)

# %%
w=sns.jointplot(x='tip',y='total_bill',data=df1,kind='hex')

# %%
w=sns.jointplot(x='tip',y='total_bill',data=df1,kind='reg')

# %%
w=sns.jointplot(x='tip',y='size',data=df1,kind='reg')

# %% [markdown]
# # Pairplot(it is also called scatter plot)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1,hue='sex')

# %%
sns.pairplot(df1,hue="smoker")

# %%
df1['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df1['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# # Dist Plot

# %%
sns.distplot(df1['tip'])

# %%
sns.distplot(df1['total_bill'])

# %%
sns.distplot(df1['size'])

# %%
sns.distplot(df1['tip'],kde=False,bins=10)

# %% [markdown]
# # Dealing with catogorical variables
# 1)Boxplot
# 2)violinplot
# 3)countplot
# 4)barplot

# %% [markdown]
# # Countplot

# %%
sns.countplot('sex',data=df1)

# %%
sns.countplot('smoker',data=df1)

# %%
sns.countplot('day',data=df1)

# %%
sns.countplot(y='sex',data=df1)

# %% [markdown]
# # Barplot

# %%
sns.barplot(x='total_bill',y='tip',data=df1)

# %%
sns.barplot(x='total_bill',y='sex',data=df1)

# %%
sns.barplot(y='total_bill',x='sex',data=df1)

# %%
sns.barplot(y='total_bill',x='size',data=df1)

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='total_bill',y='sex',data=df1)

# %%
sns.boxplot(y='total_bill',x='sex',data=df1)

# %%
sns.boxplot(y='total_bill',x='tip',data=df1)

# %%
sns.boxplot(y='total_bill',x='day',data=df1)

# %%
sns.boxplot(data=df1,orient='v')

# %%
sns.boxplot(y='total_bill',x='day',hue="smoker",data=df1)

# %%
sns.boxplot(y='total_bill',x='smoker',hue="size",data=df1)

# %% [markdown]
# # violinplot

# %%
sns.violinplot(y='total_bill',x='smoker',data=df1,palette='rainbow')

# %%
sns.violinplot(x='total_bill',y='smoker',data=df1,palette='rainbow')

# %% [markdown]
# # Data visualization on iris dataset

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
sns.barplot(x='sepal_length',y='sepal_width',data=df)

# %%
sns.boxplot(x='sepal_length',y='sepal_width',data=df)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df,kind='reg')
